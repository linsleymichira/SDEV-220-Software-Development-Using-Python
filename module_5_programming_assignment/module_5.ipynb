# %%
assert sum([1, 2, 3]) == 6, "Should be 6"

# %%
assert sum([1, 1, 1]) == 6, "Should be 6"

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")

# %%
import unittest


class TestSum(unittest.TestCase):

    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")

if __name__ == "__main_":
    unittest.main()

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

# %%
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %%
target = __import__("my_sum.py")
sum = target.sum

# %%
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

if __name__ == "__main_":
    unittest.main()

# %%
if __name__ == "__main_":
    unittest.main()

# %%
from fractions import Fraction

# %%
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)

if __name__ == "__main_":
    unittest.main()

# %% [markdown]
# ### Test Results Meaning
#
# Running the test suite from the previous block will result in **1 pass and 1 failure**:
# - **`test_list_int` will pass** because `sum([1, 2, 3])` correctly equals `6`.
# - **`test_list_fraction` will fail** because the sum of `[Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]` evaluates to `9/10`. However, our test explicitly expects the result to equal `1`. Since `9/10 != 1`, an `AssertionError` is raised.
#
# This test failure tells us that our `sum()` method is likely working correctly and returning the true mathematical sum, but our test case has an incorrect expected value. To fix it, the test should be updated to assert that it equals `Fraction(9, 10)`.
